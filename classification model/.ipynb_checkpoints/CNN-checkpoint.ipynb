# %%
import pandas as pd
from tensorflow import keras
from sklearn.model_selection import train_test_split
from data import BodyPart
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def load_csv(csv_path):
    df = pd.read_csv(csv_path)
    df.drop(['filename'],axis=1, inplace=True)
    classes = df.pop('class_name').unique()
    y = df.pop('class_no')
    
    X = df.astype('float64')
    y = keras.utils.to_categorical(y)
    
    return X, y, classes

# %%
def preprocess_data(X_train):
    processed_X_train = []
    for i in range(X_train.shape[0]):
        embedding = landmarks_to_embedding(tf.reshape(tf.convert_to_tensor(X_train.iloc[i]), (1, 51)))
        processed_X_train.append(tf.reshape(embedding, (34)))
    return tf.convert_to_tensor(processed_X_train)

# %%
def landmarks_to_embedding(landmarks_and_scores):
    """Converts the input landmarks into a pose embedding."""
    # Reshape the flat input into a matrix with shape=(17, 3)
    reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

    # Normalize landmarks 2D
    landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])
    # Flatten the normalized landmark coordinates into a vector
    embedding = keras.layers.Flatten()(landmarks)
    return embedding

# %%
def normalize_pose_landmarks(landmarks):
    """Normalizes the landmarks translation by moving the pose center to (0,0) and
    scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
    pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    pose_center = tf.expand_dims(pose_center, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to perform
    # substraction
    pose_center = tf.broadcast_to(pose_center, 
                                [tf.size(landmarks) // (17*2), 17, 2])
    landmarks = landmarks - pose_center

    # Scale the landmarks to a constant pose size
    pose_size = get_pose_size(landmarks)
    landmarks /= pose_size
    return landmarks

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
    """Calculates the center point of the two given landmarks."""
    left = tf.gather(landmarks, left_bodypart.value, axis=1)
    right = tf.gather(landmarks, right_bodypart.value, axis=1)
    center = left * 0.5 + right * 0.5
    return center

# %%
def get_pose_size(landmarks, torso_size_multiplier=2.5):
    """Calculates pose size.

    It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
    """
    # Hips center
    hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    # Shoulders center
    shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

    # Torso size as the minimum body size
    torso_size = tf.linalg.norm(shoulders_center - hips_center)
    # Pose center
    pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                     BodyPart.RIGHT_HIP)
    pose_center_new = tf.expand_dims(pose_center_new, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to
    # perform substraction
    pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

    # Dist to pose center
    d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
    # Max dist to pose center
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Normalize scale
    pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)
    return pose_size

# %%
def cnn_model(input_shape, num_classes):
    model = keras.Sequential([
        keras.layers.Conv1D(64, 3, activation='relu', input_shape=input_shape),
        keras.layers.MaxPooling1D(2),
        keras.layers.Conv1D(128, 3, activation='relu'),
        keras.layers.MaxPooling1D(2),
        keras.layers.Flatten(),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

# %%
X, y, class_names = load_csv('train_data.csv')
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15)
X_test, y_test, _ = load_csv('test_data.csv')

# %%
processed_X_train = preprocess_data(X_train)
processed_X_val =  preprocess_data(X_val)
processed_X_test = preprocess_data(X_test)
# Out:
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Reshape data for CNN
processed_X_train = tf.expand_dims(processed_X_train, axis=-1)
processed_X_val = tf.expand_dims(processed_X_val, axis=-1)
processed_X_test = tf.expand_dims(processed_X_test, axis=-1)

# %%
input_shape = processed_X_train.shape[1:]

# %%
model = cnn_model(input_shape, len(class_names))
# Out:
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(processed_X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(processed_X_val, y_val))
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 81/81 [==============================] - 1s 7ms/step - loss: 1.5106 - accuracy: 0.4630 - val_loss: 0.9985 - val_accuracy: 0.6432
# Epoch 2/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.9230 - accuracy: 0.6700 - val_loss: 0.5660 - val_accuracy: 0.8062
# Epoch 3/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5982 - accuracy: 0.7829 - val_loss: 0.3521 - val_accuracy: 0.8634
# Epoch 4/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3907 - accuracy: 0.8763 - val_loss: 0.2264 - val_accuracy: 0.9427
# Epoch 5/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.2684 - accuracy: 0.9206 - val_loss: 0.2170 - val_accuracy: 0.9251
# Epoch 6/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.1980 - accuracy: 0.9370 - val_loss: 0.1403 - val_accuracy: 0.9692
# Epoch 7/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.1528 - accuracy: 0.9510 - val_loss: 0.0794 - val_accuracy: 0.9824
# Epoch 8/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9696 - val_loss: 0.0727 - val_accuracy: 0.9780
# Epoch 9/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.1120 - accuracy: 0.9689 - val_loss: 0.0753 - val_accuracy: 0.9692
# Epoch 10/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0833 - accuracy: 0.9728 - val_loss: 0.0744 - val_accuracy: 0.9780
# Epoch 11/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0886 - accuracy: 0.9720 - val_loss: 0.0588 - val_accuracy: 0.9780
# Epoch 12/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0802 - accuracy: 0.9759 - val_loss: 0.0604 - val_accuracy: 0.9824
# Epoch 13/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0669 - accuracy: 0.9798 - val_loss: 0.0696 - val_accuracy: 0.9692
# Epoch 14/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0544 - accuracy: 0.9805 - val_loss: 0.0568 - val_accuracy: 0.9868
# Epoch 15/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9883 - val_loss: 0.0652 - val_accuracy: 0.9692
# Epoch 16/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.9860 - val_loss: 0.0669 - val_accuracy: 0.9868
# Epoch 17/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 0.9883 - val_loss: 0.0680 - val_accuracy: 0.9824
# Epoch 18/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9907 - val_loss: 0.0725 - val_accuracy: 0.9780
# Epoch 19/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 0.9969 - val_loss: 0.0721 - val_accuracy: 0.9780
# Epoch 20/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0432 - accuracy: 0.9821 - val_loss: 0.0813 - val_accuracy: 0.9692
# Epoch 21/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9922 - val_loss: 0.0699 - val_accuracy: 0.9868
# Epoch 22/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0511 - accuracy: 0.9805 - val_loss: 0.0882 - val_accuracy: 0.9824
# Epoch 23/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 0.9891 - val_loss: 0.0695 - val_accuracy: 0.9868
# Epoch 24/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9914 - val_loss: 0.0661 - val_accuracy: 0.9868
# Epoch 25/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9922 - val_loss: 0.0739 - val_accuracy: 0.9824
# Epoch 26/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9946 - val_loss: 0.0688 - val_accuracy: 0.9824
# Epoch 27/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9938 - val_loss: 0.0779 - val_accuracy: 0.9736
# Epoch 28/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0233 - accuracy: 0.9930 - val_loss: 0.0684 - val_accuracy: 0.9780
# Epoch 29/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9953 - val_loss: 0.0686 - val_accuracy: 0.9868
# Epoch 30/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 0.0725 - val_accuracy: 0.9868
# Epoch 31/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9961 - val_loss: 0.0684 - val_accuracy: 0.9868
# Epoch 32/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 0.0773 - val_accuracy: 0.9824
# Epoch 33/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9953 - val_loss: 0.0919 - val_accuracy: 0.9736
# Epoch 34/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9953 - val_loss: 0.0977 - val_accuracy: 0.9736
# Epoch 35/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9938 - val_loss: 0.1161 - val_accuracy: 0.9736
# Epoch 36/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 0.9922 - val_loss: 0.0887 - val_accuracy: 0.9824
# Epoch 37/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9977 - val_loss: 0.0900 - val_accuracy: 0.9868
# Epoch 38/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9946 - val_loss: 0.0925 - val_accuracy: 0.9868
# Epoch 39/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9992 - val_loss: 0.0865 - val_accuracy: 0.9868
# Epoch 40/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9914 - val_loss: 0.0786 - val_accuracy: 0.9868
# Epoch 41/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.0890 - val_accuracy: 0.9868
# Epoch 42/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 0.9868
# Epoch 43/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.0888 - val_accuracy: 0.9824
# Epoch 44/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9938 - val_loss: 0.1081 - val_accuracy: 0.9736
# Epoch 45/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9961 - val_loss: 0.0889 - val_accuracy: 0.9868
# Epoch 46/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9984 - val_loss: 0.0914 - val_accuracy: 0.9868
# Epoch 47/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 0.9914 - val_loss: 0.1174 - val_accuracy: 0.9780
# Epoch 48/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.1171 - val_accuracy: 0.9780
# Epoch 49/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.1041 - val_accuracy: 0.9868
# Epoch 50/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9984 - val_loss: 0.1011 - val_accuracy: 0.9868
# Epoch 51/200
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9961 - val_loss: 0.0974 - val_accuracy: 0.9868
# Epoch 52/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9946 - val_loss: 0.0936 - val_accuracy: 0.9868
# Epoch 53/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9992 - val_loss: 0.0764 - val_accuracy: 0.9868
# Epoch 54/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9868
# Epoch 55/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.1676 - val_accuracy: 0.9736
# Epoch 56/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.0852 - val_accuracy: 0.9868
# Epoch 57/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0908 - val_accuracy: 0.9868
# Epoch 58/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0848 - val_accuracy: 0.9868
# Epoch 59/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 0.9938 - val_loss: 0.1118 - val_accuracy: 0.9824
# Epoch 60/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 0.9914 - val_loss: 0.1066 - val_accuracy: 0.9780
# Epoch 61/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9946 - val_loss: 0.1016 - val_accuracy: 0.9824
# Epoch 62/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.1128 - val_accuracy: 0.9780
# Epoch 63/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.1089 - val_accuracy: 0.9780
# Epoch 64/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.1026 - val_accuracy: 0.9780
# Epoch 65/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0978 - val_accuracy: 0.9780
# Epoch 66/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.0979 - val_accuracy: 0.9824
# Epoch 67/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9946 - val_loss: 0.0801 - val_accuracy: 0.9868
# Epoch 68/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.1108 - val_accuracy: 0.9868
# Epoch 69/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9868
# Epoch 70/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0971 - val_accuracy: 0.9868
# Epoch 71/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9868
# Epoch 72/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9868
# Epoch 73/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.1135 - val_accuracy: 0.9868
# Epoch 74/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.1296 - val_accuracy: 0.9780
# Epoch 75/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9938 - val_loss: 0.1159 - val_accuracy: 0.9780
# Epoch 76/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.0937 - val_accuracy: 0.9868
# Epoch 77/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.1076 - val_accuracy: 0.9868
# Epoch 78/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.1148 - val_accuracy: 0.9824
# Epoch 79/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9977 - val_loss: 0.1018 - val_accuracy: 0.9868
# Epoch 80/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.1006 - val_accuracy: 0.9868
# Epoch 81/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9969 - val_loss: 0.0993 - val_accuracy: 0.9868
# Epoch 82/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.1480 - val_accuracy: 0.9824
# Epoch 83/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 0.9977 - val_loss: 0.1544 - val_accuracy: 0.9824
# Epoch 84/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9930 - val_loss: 0.1476 - val_accuracy: 0.9780
# Epoch 85/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9977 - val_loss: 0.1330 - val_accuracy: 0.9780
# Epoch 86/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.1140 - val_accuracy: 0.9868
# Epoch 87/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9969 - val_loss: 0.1232 - val_accuracy: 0.9824
# Epoch 88/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9868
# Epoch 89/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1232 - val_accuracy: 0.9868
# Epoch 90/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.1595 - val_accuracy: 0.9824
# Epoch 91/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.1304 - val_accuracy: 0.9824
# Epoch 92/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9868
# Epoch 93/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.1178 - val_accuracy: 0.9824
# Epoch 94/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9824
# Epoch 95/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9824
# Epoch 96/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0992 - val_accuracy: 0.9868
# Epoch 97/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 0.9868
# Epoch 98/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9969 - val_loss: 0.1306 - val_accuracy: 0.9824
# Epoch 99/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.1299 - val_accuracy: 0.9780
# Epoch 100/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 0.9977 - val_loss: 0.1184 - val_accuracy: 0.9824
# Epoch 101/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9977 - val_loss: 0.1014 - val_accuracy: 0.9868
# Epoch 102/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.1250 - val_accuracy: 0.9824
# Epoch 103/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9736
# Epoch 104/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9984 - val_loss: 0.1359 - val_accuracy: 0.9780
# Epoch 105/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.1235 - val_accuracy: 0.9868
# Epoch 106/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.1327 - val_accuracy: 0.9868
# Epoch 107/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.1404 - val_accuracy: 0.9824
# Epoch 108/200
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.1494 - val_accuracy: 0.9824
# Epoch 109/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.1350 - val_accuracy: 0.9868
# Epoch 110/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9961 - val_loss: 0.1441 - val_accuracy: 0.9824
# Epoch 111/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9824
# Epoch 112/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.1086 - val_accuracy: 0.9868
# Epoch 113/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9977 - val_loss: 0.1298 - val_accuracy: 0.9868
# Epoch 114/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9922 - val_loss: 0.1097 - val_accuracy: 0.9824
# Epoch 115/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.1213 - val_accuracy: 0.9780
# Epoch 116/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.1166 - val_accuracy: 0.9824
# Epoch 117/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.1089 - val_accuracy: 0.9868
# Epoch 118/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.1151 - val_accuracy: 0.9868
# Epoch 119/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9977 - val_loss: 0.1215 - val_accuracy: 0.9868
# Epoch 120/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1261 - val_accuracy: 0.9824
# Epoch 121/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.1221 - val_accuracy: 0.9868
# Epoch 122/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9824
# Epoch 123/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9868
# Epoch 124/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.1378 - val_accuracy: 0.9824
# Epoch 125/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.1286 - val_accuracy: 0.9780
# Epoch 126/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9824
# Epoch 127/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.1480 - val_accuracy: 0.9824
# Epoch 128/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.1292 - val_accuracy: 0.9868
# Epoch 129/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.1589 - val_accuracy: 0.9824
# Epoch 130/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.1571 - val_accuracy: 0.9824
# Epoch 131/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9969 - val_loss: 0.1625 - val_accuracy: 0.9824
# Epoch 132/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.1622 - val_accuracy: 0.9824
# Epoch 133/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.1409 - val_accuracy: 0.9868
# Epoch 134/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.1525 - val_accuracy: 0.9868
# Epoch 135/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 0.9977 - val_loss: 0.1621 - val_accuracy: 0.9824
# Epoch 136/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9868
# Epoch 137/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.1542 - val_accuracy: 0.9824
# Epoch 138/200
# 81/81 [==============================] - 0s 4ms/step - loss: 5.9114e-04 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9824
# Epoch 139/200
# 81/81 [==============================] - 0s 5ms/step - loss: 3.7599e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9824
# Epoch 140/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 0.9984 - val_loss: 0.1429 - val_accuracy: 0.9780
# Epoch 141/200
# 81/81 [==============================] - 0s 4ms/step - loss: 8.9195e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9824
# Epoch 142/200
# 81/81 [==============================] - 0s 4ms/step - loss: 5.7799e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9824
# Epoch 143/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9824
# Epoch 144/200
# 81/81 [==============================] - 0s 4ms/step - loss: 9.5461e-04 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9824
# Epoch 145/200
# 81/81 [==============================] - 0s 4ms/step - loss: 2.9119e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9824
# Epoch 146/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9930 - val_loss: 0.1664 - val_accuracy: 0.9824
# Epoch 147/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.1327 - val_accuracy: 0.9868
# Epoch 148/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9977 - val_loss: 0.1074 - val_accuracy: 0.9868
# Epoch 149/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9977 - val_loss: 0.2031 - val_accuracy: 0.9780
# Epoch 150/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9992 - val_loss: 0.1272 - val_accuracy: 0.9824
# Epoch 151/200
# 81/81 [==============================] - 0s 4ms/step - loss: 7.6856e-04 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9824
# Epoch 152/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.1296 - val_accuracy: 0.9824
# Epoch 153/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9824
# Epoch 154/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9824
# Epoch 155/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1854 - val_accuracy: 0.9824
# Epoch 156/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.1260 - val_accuracy: 0.9868
# Epoch 157/200
# 81/81 [==============================] - 0s 4ms/step - loss: 9.2036e-04 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9824
# Epoch 158/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1276 - val_accuracy: 0.9868
# Epoch 159/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 0.1392 - val_accuracy: 0.9824
# Epoch 160/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.1729 - val_accuracy: 0.9824
# Epoch 161/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9824
# Epoch 162/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9824
# Epoch 163/200
# 81/81 [==============================] - 0s 4ms/step - loss: 2.5619e-04 - accuracy: 1.0000 - val_loss: 0.1803 - val_accuracy: 0.9824
# Epoch 164/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 0.1829 - val_accuracy: 0.9824
# Epoch 165/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1744 - val_accuracy: 0.9824
# Epoch 166/200
# 81/81 [==============================] - 0s 4ms/step - loss: 9.7709e-04 - accuracy: 1.0000 - val_loss: 0.1813 - val_accuracy: 0.9824
# Epoch 167/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.1739 - val_accuracy: 0.9824
# Epoch 168/200
# 81/81 [==============================] - 0s 4ms/step - loss: 5.4648e-04 - accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 0.9824
# Epoch 169/200
# 81/81 [==============================] - 0s 4ms/step - loss: 7.2620e-04 - accuracy: 0.9992 - val_loss: 0.1579 - val_accuracy: 0.9824
# Epoch 170/200
# 81/81 [==============================] - 0s 4ms/step - loss: 8.0449e-04 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9824
# Epoch 171/200
# 81/81 [==============================] - 0s 4ms/step - loss: 3.9171e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9824
# Epoch 172/200
# 81/81 [==============================] - 0s 4ms/step - loss: 3.4057e-04 - accuracy: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.9824
# Epoch 173/200
# 81/81 [==============================] - 0s 4ms/step - loss: 5.2690e-04 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9824
# Epoch 174/200
# 81/81 [==============================] - 0s 4ms/step - loss: 6.6191e-04 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9824
# Epoch 175/200
# 81/81 [==============================] - 0s 4ms/step - loss: 1.7256e-04 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9824
# Epoch 176/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.2421 - val_accuracy: 0.9780
# Epoch 177/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.2185 - val_accuracy: 0.9824
# Epoch 178/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.2034 - val_accuracy: 0.9780
# Epoch 179/200
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.5421 - val_accuracy: 0.9604
# Epoch 180/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 0.9891 - val_loss: 0.1721 - val_accuracy: 0.9824
# Epoch 181/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.1631 - val_accuracy: 0.9824
# Epoch 182/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.1458 - val_accuracy: 0.9868
# Epoch 183/200
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9992 - val_loss: 0.1354 - val_accuracy: 0.9868
# Epoch 184/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.1415 - val_accuracy: 0.9868
# Epoch 185/200
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 0.1591 - val_accuracy: 0.9868
# Epoch 186/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.2018 - val_accuracy: 0.9780
# Epoch 187/200
# 81/81 [==============================] - 0s 4ms/step - loss: 8.7651e-04 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9780
# Epoch 188/200
# 81/81 [==============================] - 0s 4ms/step - loss: 1.7094e-04 - accuracy: 1.0000 - val_loss: 0.1835 - val_accuracy: 0.9780
# Epoch 189/200
# 81/81 [==============================] - 0s 4ms/step - loss: 5.8143e-04 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9824
# Epoch 190/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9984 - val_loss: 0.2070 - val_accuracy: 0.9780
# Epoch 191/200
# 81/81 [==============================] - 0s 4ms/step - loss: 2.2091e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9780
# Epoch 192/200
# 81/81 [==============================] - 0s 4ms/step - loss: 4.8742e-04 - accuracy: 1.0000 - val_loss: 0.1796 - val_accuracy: 0.9868
# Epoch 193/200
# 81/81 [==============================] - 0s 4ms/step - loss: 4.3193e-04 - accuracy: 1.0000 - val_loss: 0.1779 - val_accuracy: 0.9868
# Epoch 194/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 0.1886 - val_accuracy: 0.9868
# Epoch 195/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.1733 - val_accuracy: 0.9868
# Epoch 196/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 0.9984 - val_loss: 0.2133 - val_accuracy: 0.9824
# Epoch 197/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.1948 - val_accuracy: 0.9824
# Epoch 198/200
# 81/81 [==============================] - 0s 4ms/step - loss: 4.4685e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9824
# Epoch 199/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.1874 - val_accuracy: 0.9780
# Epoch 200/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.1736 - val_accuracy: 0.9868

# %%
print('-----------------EVALUATION----------------')
loss, accuracy = model.evaluate(processed_X_test, y_test)
print('LOSS: ', loss)
print("Test ACCURACY: ", accuracy)
# Out:
# -----------------EVALUATION----------------
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 0.9966
# LOSS:  0.019894376397132874
# Test ACCURACY:  0.9965792298316956

# %%
loss, accuracy = model.evaluate(processed_X_train, y_train)
print('LOSS: ', loss)
print("Train ACCURACY: ", accuracy)
# Out:
# 41/41 [==============================] - 0s 3ms/step - loss: 3.6381e-06 - accuracy: 1.0000
# LOSS:  3.638076805145829e-06
# Train ACCURACY:  1.0

# %%
loss, accuracy = model.evaluate(processed_X_val, y_val)
print('LOSS: ', loss)
print("Train ACCURACY: ", accuracy)
# Out:
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1736 - accuracy: 0.9868
# LOSS:  0.1735774427652359
# Train ACCURACY:  0.9867841601371765

# %%
model.save('CNN_model.keras')
