# %%
import pandas as pd
from tensorflow import keras
from sklearn.model_selection import train_test_split
from data import BodyPart
import tensorflowjs as tfjs
# Out:
# WARNING:root:Failure to load the inference.so custom c++ tensorflow ops. This error is likely caused the version of TensorFlow and TensorFlow Decision Forests are not compatible. Full error:C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\inference.so not found
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[13], line 5
#       3 from sklearn.model_selection import train_test_split
#       4 from data import BodyPart
# ----> 5 import tensorflowjs as tfjs
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflowjs\__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports
# ---> 21 from tensorflowjs import converters
#      22 from tensorflowjs import quantization
#      23 from tensorflowjs import version
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflowjs\converters\__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports,line-too-long
# ---> 21 from tensorflowjs.converters.converter import convert
#      22 from tensorflowjs.converters.keras_h5_conversion import save_keras_model
#      23 from tensorflowjs.converters.keras_tfjs_loader import deserialize_keras_model
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflowjs\converters\converter.py:37
#      35 from tensorflowjs.converters import keras_h5_conversion as conversion
#      36 from tensorflowjs.converters import keras_tfjs_loader
# ---> 37 from tensorflowjs.converters import tf_saved_model_conversion_v2
#      38 from zipfile import ZipFile, is_zipfile
#      41 def dispatch_keras_h5_to_tfjs_layers_model_conversion(
#      42     h5_path, output_dir=None, quantization_dtype_map=None,
#      43     split_weights_by_layer=False,
#      44     weight_shard_size_bytes=1024 * 1024 * 4,
#      45     metadata=None):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflowjs\converters\tf_saved_model_conversion_v2.py:28
#      25 from zipfile import ZipFile
#      27 # Required to load saved models that use TFDF.
# ---> 28 import tensorflow_decision_forests
#      29 import tensorflow as tf
#      30 from tensorflow.core.framework import function_pb2
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\__init__.py:64
#      60 from tensorflow_decision_forests.tensorflow import check_version
#      62 check_version.check_version(__version__, compatible_tf_versions)
# ---> 64 from tensorflow_decision_forests import keras
#      65 from tensorflow_decision_forests.component import py_tree
#      66 from tensorflow_decision_forests.component.builder import builder
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\keras\__init__.py:53
#      15 """Decision Forest in a Keras Model.
#      16
#      17 Usage example:
#    (...)
#      48 ```
#      49 """
#      51 from typing import Callable, List
# ---> 53 from tensorflow_decision_forests.keras import core
#      54 from tensorflow_decision_forests.keras import wrappers
#      56 # Utility classes
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\keras\core.py:62
#      60 from tensorflow_decision_forests.component.inspector import inspector as inspector_lib
#      61 from tensorflow_decision_forests.component.tuner import tuner as tuner_lib
# ---> 62 from tensorflow_decision_forests.keras import core_inference
#      63 from tensorflow_decision_forests.tensorflow import cc_logging
#      64 from tensorflow_decision_forests.tensorflow import core as tf_core
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\keras\core_inference.py:36
#      34 from tensorflow_decision_forests.tensorflow import core_inference as tf_core
#      35 from tensorflow_decision_forests.tensorflow import tf_logging
# ---> 36 from tensorflow_decision_forests.tensorflow.ops.inference import api as tf_op
#      37 from yggdrasil_decision_forests.learner import abstract_learner_pb2
#      38 from yggdrasil_decision_forests.learner.multitasker import multitasker_pb2
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\api.py:179
#     177 from tensorflow_decision_forests.component.inspector import inspector as inspector_lib
#     178 from tensorflow_decision_forests.tensorflow import tf1_compatibility
# --> 179 from tensorflow_decision_forests.tensorflow.ops.inference import op
#     180 from yggdrasil_decision_forests.dataset import data_spec_pb2
#     181 from yggdrasil_decision_forests.model import abstract_model_pb2
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\op.py:15
#       1 # Copyright 2021 Google LLC.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from tensorflow_decision_forests.tensorflow.ops.inference.op_dynamic import *
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\op_dynamic.py:24
#      22 except Exception as e:
#      23   check_version.info_fail_to_load_custom_op(e, "inference.so")
# ---> 24   raise e
#      26 # Importing all the symbols.
#      27 module = sys.modules[__name__]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\op_dynamic.py:21
#      18 import sys
#      20 try:
# ---> 21   ops = tf.load_op_library(resource_loader.get_path_to_datafile("inference.so"))
#      22 except Exception as e:
#      23   check_version.info_fail_to_load_custom_op(e, "inference.so")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\load_library.py:54, in load_op_library(library_filename)
#      31 @tf_export('load_op_library')
#      32 def load_op_library(library_filename):
#      33   """Loads a TensorFlow plugin, containing custom ops and kernels.
#      34
#      35   Pass "library_filename" to a platform-specific mechanism for dynamically
#    (...)
#      52     RuntimeError: when unable to load the library or get the python wrappers.
#      53   """
# ---> 54   lib_handle = py_tf.TF_LoadLibrary(library_filename)
#      55   try:
#      56     wrappers = _pywrap_python_op_gen.GetPythonWrappers(
#      57         py_tf.TF_GetOpList(lib_handle))
#
# NotFoundError: C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\inference.so not found

# %%
pip show tensorflow_decision_forests
# Out:
# Name: tensorflow-decision-forests
# Version: 1.8.1
# Summary: Collection of training and inference decision forest algorithms.
# Home-page: https://github.com/tensorflow/decision-forests
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\dell\appdata\roaming\python\python310\site-packages
# Requires: absl-py, numpy, pandas, six, tensorflow, wheel, wurlitzer
# Required-by: tensorflowjs
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\users\dell\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dell\appdata\roaming\python\python310\site-packages)

# %%
def load_csv(csv_path):
    df = pd.read_csv(csv_path)
    df.drop(['filename'],axis=1, inplace=True)
    classes = df.pop('class_name').unique()
    y = df.pop('class_no')
    
    X = df.astype('float64')
    y = keras.utils.to_categorical(y)
    
    return X, y, classes

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
    """Calculates the center point of the two given landmarks."""
    left = tf.gather(landmarks, left_bodypart.value, axis=1)
    right = tf.gather(landmarks, right_bodypart.value, axis=1)
    center = left * 0.5 + right * 0.5
    return center

# %%
def get_pose_size(landmarks, torso_size_multiplier=2.5):
    """Calculates pose size.

    It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
    """
    # Hips center
    hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    # Shoulders center
    shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

    # Torso size as the minimum body size
    torso_size = tf.linalg.norm(shoulders_center - hips_center)
    # Pose center
    pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                     BodyPart.RIGHT_HIP)
    pose_center_new = tf.expand_dims(pose_center_new, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to
    # perform substraction
    pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

    # Dist to pose center
    d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
    # Max dist to pose center
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Normalize scale
    pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)
    return pose_size

# %%
def normalize_pose_landmarks(landmarks):
    """Normalizes the landmarks translation by moving the pose center to (0,0) and
    scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
    pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    pose_center = tf.expand_dims(pose_center, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to perform
    # substraction
    pose_center = tf.broadcast_to(pose_center, 
                                [tf.size(landmarks) // (17*2), 17, 2])
    landmarks = landmarks - pose_center

    # Scale the landmarks to a constant pose size
    pose_size = get_pose_size(landmarks)
    landmarks /= pose_size
    return landmarks

# %%
def landmarks_to_embedding(landmarks_and_scores):
    """Converts the input landmarks into a pose embedding."""
    # Reshape the flat input into a matrix with shape=(17, 3)
    reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

    # Normalize landmarks 2D
    landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])
    # Flatten the normalized landmark coordinates into a vector
    embedding = keras.layers.Flatten()(landmarks)
    return embedding

# %%
def preprocess_data(X_train):
    processed_X_train = []
    for i in range(X_train.shape[0]):
        embedding = landmarks_to_embedding(tf.reshape(tf.convert_to_tensor(X_train.iloc[i]), (1, 51)))
        processed_X_train.append(tf.reshape(embedding, (34)))
    return tf.convert_to_tensor(processed_X_train)

# %%
X, y, class_names = load_csv('train_data.csv')
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15)
X_test, y_test, _ = load_csv('test_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 X, y, class_names = load_csv('train_data.csv')
#       2 X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15)
#       3 X_test, y_test, _ = load_csv('test_data.csv')
#
# Cell In[17], line 2, in load_csv(csv_path)
#       1 def load_csv(csv_path):
# ----> 2     df = pd.read_csv(csv_path)
#       3     df.drop(['filename'],axis=1, inplace=True)
#       4     classes = df.pop('class_name').unique()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train_data.csv'

# %%
processed_X_train = preprocess_data(X_train)
processed_X_val =  preprocess_data(X_val)
processed_X_test = preprocess_data(X_test)

# %%
inputs = tf.keras.Input(shape=(34, ))
layer = keras.layers.Dense(128, activation=tf.nn.relu6)(inputs)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

# %%
model = keras.Model(inputs, outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# checkpoint_path = "weights.best.hdf5"
# checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
#                              monitor='val_accuracy',
#                              verbose=1,
#                              save_best_only=True,
#                              mode='max')
# earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', 
#                                        patience=20)

# %%
history = model.fit(processed_X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(processed_X_val, y_val))
# Out:
# Epoch 1/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3555 - loss: 1.8874 - val_accuracy: 0.5419 - val_loss: 1.1365
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5571 - loss: 1.1918 - val_accuracy: 0.8282 - val_loss: 0.7370
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6363 - loss: 0.9532 - val_accuracy: 0.8282 - val_loss: 0.5501
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7404 - loss: 0.7438 - val_accuracy: 0.8546 - val_loss: 0.4394
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7409 - loss: 0.6947 - val_accuracy: 0.8855 - val_loss: 0.3577
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7779 - loss: 0.6016 - val_accuracy: 0.9339 - val_loss: 0.3065
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8029 - loss: 0.5483 - val_accuracy: 0.9251 - val_loss: 0.2763
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8251 - loss: 0.4823 - val_accuracy: 0.9383 - val_loss: 0.2390
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8589 - loss: 0.3994 - val_accuracy: 0.9515 - val_loss: 0.2136
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.3596 - val_accuracy: 0.9515 - val_loss: 0.1898
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8823 - loss: 0.3678 - val_accuracy: 0.9515 - val_loss: 0.1923
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8814 - loss: 0.3807 - val_accuracy: 0.9604 - val_loss: 0.1653
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8947 - loss: 0.3237 - val_accuracy: 0.9559 - val_loss: 0.1689
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8980 - loss: 0.3049 - val_accuracy: 0.9604 - val_loss: 0.1495
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9110 - loss: 0.2684 - val_accuracy: 0.9604 - val_loss: 0.1407
# Epoch 16/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2898 - val_accuracy: 0.9692 - val_loss: 0.1350
# Epoch 17/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8984 - loss: 0.2696 - val_accuracy: 0.9604 - val_loss: 0.1327
# Epoch 18/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9216 - loss: 0.2459 - val_accuracy: 0.9648 - val_loss: 0.1297
# Epoch 19/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9215 - loss: 0.2558 - val_accuracy: 0.9692 - val_loss: 0.1216
# Epoch 20/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9104 - loss: 0.2435 - val_accuracy: 0.9648 - val_loss: 0.1114
# Epoch 21/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9282 - loss: 0.2181 - val_accuracy: 0.9604 - val_loss: 0.1155
# Epoch 22/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9261 - loss: 0.2046 - val_accuracy: 0.9692 - val_loss: 0.1145
# Epoch 23/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9280 - loss: 0.2103 - val_accuracy: 0.9604 - val_loss: 0.1189
# Epoch 24/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9389 - loss: 0.2271 - val_accuracy: 0.9692 - val_loss: 0.1117
# Epoch 25/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9373 - loss: 0.1891 - val_accuracy: 0.9736 - val_loss: 0.1088
# Epoch 26/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9511 - loss: 0.1715 - val_accuracy: 0.9736 - val_loss: 0.1058
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9489 - loss: 0.1704 - val_accuracy: 0.9736 - val_loss: 0.1023
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9580 - loss: 0.1407 - val_accuracy: 0.9780 - val_loss: 0.1098
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9550 - loss: 0.1698 - val_accuracy: 0.9736 - val_loss: 0.1073
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9446 - loss: 0.1993 - val_accuracy: 0.9824 - val_loss: 0.1015
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9487 - loss: 0.1509 - val_accuracy: 0.9780 - val_loss: 0.1004
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9443 - loss: 0.1512 - val_accuracy: 0.9824 - val_loss: 0.0986
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1380 - val_accuracy: 0.9736 - val_loss: 0.1011
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9436 - loss: 0.1536 - val_accuracy: 0.9780 - val_loss: 0.0961
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9860 - loss: 0.0397 - val_accuracy: 0.9780 - val_loss: 0.1146
# Epoch 103/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9899 - loss: 0.0372 - val_accuracy: 0.9824 - val_loss: 0.1225
# Epoch 104/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.0339 - val_accuracy: 0.9824 - val_loss: 0.1161
# Epoch 105/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9864 - loss: 0.0443 - val_accuracy: 0.9780 - val_loss: 0.1195
# Epoch 106/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9864 - loss: 0.0421 - val_accuracy: 0.9868 - val_loss: 0.1214
# Epoch 107/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9799 - loss: 0.0518 - val_accuracy: 0.9780 - val_loss: 0.1122
# Epoch 108/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0220 - val_accuracy: 0.9824 - val_loss: 0.1191
# Epoch 109/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.0372 - val_accuracy: 0.9868 - val_loss: 0.1237
# Epoch 110/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9869 - loss: 0.0443 - val_accuracy: 0.9824 - val_loss: 0.1284
# Epoch 111/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0495 - val_accuracy: 0.9868 - val_loss: 0.1373
# Epoch 112/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9897 - loss: 0.0349 - val_accuracy: 0.9868 - val_loss: 0.1332
# Epoch 113/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0295 - val_accuracy: 0.9780 - val_loss: 0.1342
# Epoch 114/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9835 - loss: 0.0595 - val_accuracy: 0.9868 - val_loss: 0.1319
# Epoch 115/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9897 - loss: 0.0322 - val_accuracy: 0.9780 - val_loss: 0.1261
# Epoch 116/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9882 - loss: 0.0331 - val_accuracy: 0.9868 - val_loss: 0.1359
# Epoch 117/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0244 - val_accuracy: 0.9780 - val_loss: 0.1331
# Epoch 118/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0242 - val_accuracy: 0.9780 - val_loss: 0.1309
# Epoch 119/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.0421 - val_accuracy: 0.9780 - val_loss: 0.1260
# Epoch 120/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0352 - val_accuracy: 0.9824 - val_loss: 0.1238
# Epoch 121/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.0294 - val_accuracy: 0.9824 - val_loss: 0.1249
# Epoch 122/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0279 - val_accuracy: 0.9824 - val_loss: 0.1265
# Epoch 123/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0374 - val_accuracy: 0.9780 - val_loss: 0.1339
# Epoch 124/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9864 - loss: 0.0313 - val_accuracy: 0.9780 - val_loss: 0.1313
# Epoch 125/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0284 - val_accuracy: 0.9824 - val_loss: 0.1330
# Epoch 126/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0297 - val_accuracy: 0.9780 - val_loss: 0.1352
# Epoch 127/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0256 - val_accuracy: 0.9780 - val_loss: 0.1389
# Epoch 128/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0590 - val_accuracy: 0.9780 - val_loss: 0.1403
# Epoch 129/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.0268 - val_accuracy: 0.9736 - val_loss: 0.1335
# Epoch 130/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9953 - loss: 0.0209 - val_accuracy: 0.9824 - val_loss: 0.1300
# Epoch 131/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0211 - val_accuracy: 0.9824 - val_loss: 0.1266
# Epoch 132/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0262 - val_accuracy: 0.9824 - val_loss: 0.1327
# Epoch 133/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0265 - val_accuracy: 0.9824 - val_loss: 0.1282
# Epoch 134/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.0444 - val_accuracy: 0.9824 - val_loss: 0.1323
# Epoch 135/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0181 - val_accuracy: 0.9824 - val_loss: 0.1273
# Epoch 136/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0356 - val_accuracy: 0.9824 - val_loss: 0.1294
# Epoch 137/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0442 - val_accuracy: 0.9780 - val_loss: 0.1227
# Epoch 138/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9900 - loss: 0.0217 - val_accuracy: 0.9780 - val_loss: 0.1300
# Epoch 139/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0256 - val_accuracy: 0.9780 - val_loss: 0.1334
# Epoch 140/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.0401 - val_accuracy: 0.9824 - val_loss: 0.1311
# Epoch 141/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9832 - loss: 0.0433 - val_accuracy: 0.9736 - val_loss: 0.1223
# Epoch 142/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9957 - loss: 0.0157 - val_accuracy: 0.9824 - val_loss: 0.1175
# Epoch 143/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0223 - val_accuracy: 0.9780 - val_loss: 0.1267
# Epoch 144/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.0505 - val_accuracy: 0.9780 - val_loss: 0.1188
# Epoch 145/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0247 - val_accuracy: 0.9780 - val_loss: 0.1315
# Epoch 146/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0208 - val_accuracy: 0.9780 - val_loss: 0.1253
# Epoch 147/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0191 - val_accuracy: 0.9780 - val_loss: 0.1292
# Epoch 148/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0289 - val_accuracy: 0.9780 - val_loss: 0.1288
# Epoch 149/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.0251 - val_accuracy: 0.9780 - val_loss: 0.1338
# Epoch 150/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0319 - val_accuracy: 0.9780 - val_loss: 0.1408
# Epoch 151/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.0246 - val_accuracy: 0.9824 - val_loss: 0.1273
# Epoch 152/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.0214 - val_accuracy: 0.9736 - val_loss: 0.1283
# Epoch 153/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.0239 - val_accuracy: 0.9780 - val_loss: 0.1271
# Epoch 154/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0344 - val_accuracy: 0.9780 - val_loss: 0.1199
# Epoch 155/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.0278 - val_accuracy: 0.9780 - val_loss: 0.1262
# Epoch 156/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.0299 - val_accuracy: 0.9780 - val_loss: 0.1342
# Epoch 157/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0247 - val_accuracy: 0.9780 - val_loss: 0.1337
# Epoch 158/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.0352 - val_accuracy: 0.9780 - val_loss: 0.1374
# Epoch 159/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9950 - loss: 0.0195 - val_accuracy: 0.9824 - val_loss: 0.1325
# Epoch 160/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.0263 - val_accuracy: 0.9780 - val_loss: 0.1334
# Epoch 161/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0259 - val_accuracy: 0.9736 - val_loss: 0.1205
# Epoch 162/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9884 - loss: 0.0351 - val_accuracy: 0.9780 - val_loss: 0.1325
# Epoch 163/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0288 - val_accuracy: 0.9736 - val_loss: 0.1350
# Epoch 164/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0180 - val_accuracy: 0.9780 - val_loss: 0.1350
# Epoch 165/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9937 - loss: 0.0217 - val_accuracy: 0.9824 - val_loss: 0.1258
# Epoch 166/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0164 - val_accuracy: 0.9824 - val_loss: 0.1207
# Epoch 167/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9895 - loss: 0.0341 - val_accuracy: 0.9780 - val_loss: 0.1263
# Epoch 168/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0199 - val_accuracy: 0.9780 - val_loss: 0.1251
# Epoch 169/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.0216 - val_accuracy: 0.9780 - val_loss: 0.1387
# Epoch 170/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0109 - val_accuracy: 0.9780 - val_loss: 0.1412
# Epoch 171/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0192 - val_accuracy: 0.9780 - val_loss: 0.1355
# Epoch 172/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9963 - loss: 0.0229 - val_accuracy: 0.9780 - val_loss: 0.1368
# Epoch 173/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9937 - loss: 0.0209 - val_accuracy: 0.9824 - val_loss: 0.1335
# Epoch 174/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0178 - val_accuracy: 0.9780 - val_loss: 0.1317
# Epoch 175/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0177 - val_accuracy: 0.9780 - val_loss: 0.1208
# Epoch 176/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9875 - loss: 0.0315 - val_accuracy: 0.9780 - val_loss: 0.1316
# Epoch 177/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9932 - loss: 0.0239 - val_accuracy: 0.9780 - val_loss: 0.1301
# Epoch 178/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9882 - loss: 0.0363 - val_accuracy: 0.9780 - val_loss: 0.1319
# Epoch 179/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.0266 - val_accuracy: 0.9780 - val_loss: 0.1324
# Epoch 180/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0242 - val_accuracy: 0.9780 - val_loss: 0.1337
# Epoch 181/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0132 - val_accuracy: 0.9780 - val_loss: 0.1370
# Epoch 182/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0170 - val_accuracy: 0.9780 - val_loss: 0.1552
# Epoch 183/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0316 - val_accuracy: 0.9780 - val_loss: 0.1350
# Epoch 184/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9884 - loss: 0.0344 - val_accuracy: 0.9780 - val_loss: 0.1516
# Epoch 185/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9902 - loss: 0.0246 - val_accuracy: 0.9780 - val_loss: 0.1339
# Epoch 186/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9950 - loss: 0.0173 - val_accuracy: 0.9780 - val_loss: 0.1416
# Epoch 187/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9963 - loss: 0.0121 - val_accuracy: 0.9824 - val_loss: 0.1382
# Epoch 188/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0155 - val_accuracy: 0.9824 - val_loss: 0.1520
# Epoch 189/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0262 - val_accuracy: 0.9780 - val_loss: 0.1575
# Epoch 190/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0132 - val_accuracy: 0.9780 - val_loss: 0.1549
# Epoch 191/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9957 - loss: 0.0176 - val_accuracy: 0.9736 - val_loss: 0.1450
# Epoch 192/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0155 - val_accuracy: 0.9780 - val_loss: 0.1467
# Epoch 193/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9888 - loss: 0.0305 - val_accuracy: 0.9780 - val_loss: 0.1564
# Epoch 194/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0128 - val_accuracy: 0.9780 - val_loss: 0.1487
# Epoch 195/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0151 - val_accuracy: 0.9780 - val_loss: 0.1452
# Epoch 196/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0162 - val_accuracy: 0.9824 - val_loss: 0.1512
# Epoch 197/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0177 - val_accuracy: 0.9780 - val_loss: 0.1528
# Epoch 198/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9875 - loss: 0.0392 - val_accuracy: 0.9736 - val_loss: 0.1619
# Epoch 199/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0295 - val_accuracy: 0.9780 - val_loss: 0.1564
# Epoch 200/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0189 - val_accuracy: 0.9780 - val_loss: 0.1570

# %%
print('-----------------EVAUATION----------------')
loss, accuracy = model.evaluate(processed_X_test, y_test)
print('LOSS: ', loss)
print("ACCURACY: ", accuracy)
# Out:
# -----------------EVAUATION----------------
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9993 - loss: 0.0017
# LOSS:  0.007817092351615429
# ACCURACY:  0.9965792298316956

# %%
model.save('my_model.keras')
